# %%
from elevenlabs import generate, play, set_api_key

set_api_key(
    "sk_9fc2b48d11d6e4af926264d2b604f57fdf7e00a5cad16f61"
)  # Check the guide on how to get a free API key: https://docs.elevenlabs.io/authentication/01-xi-api-key

audio = generate(
    text="help!! Help! I can't get out of this room!!",
    voice="George - royal and elegant",
)

play(audio, use_ffmpeg=False)
